# %% [markdown]
# Stewart Merritt
# Oct 2, 2024
# Project 1 part 2

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\stewa\Downloads\Majors Survey Results - Fall 2024.csv")

df.head()
# Out:
#                     Timestamp Which course are you enrolled in?  \
# 0  2024/09/09 12:33:58 PM AST        CMP 128 Computer Science I
# 1   2024/09/09 6:00:11 PM AST                               NaN
# 2   2024/09/10 9:00:12 AM AST        CMP 128 Computer Science I
# 3  2024/09/10 12:34:53 PM AST        CMP 128 Computer Science I
# 4   2024/09/10 3:06:47 PM AST        CMP 128 Computer Science I
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %% [markdown]
# looking at the data set

# %%
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?
# count                                          62.000000
# mean                                            3.580645
# std                                             1.079593
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
df.shape
# Out:
# (197, 90)

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                               object
# Which course are you enrolled in?                                                                                                                       object
# How did you hear about County College of Morris? [CCM Web site]                                                                                         object
# How did you hear about County College of Morris? [Social Media]                                                                                         object
# How did you hear about County College of Morris? [Community Event]                                                                                      object
#                                                                                                                                                         ...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %% [markdown]
# Renaming columns to not have spaces

# %%
# Rename columns to lower case with underscores
df.columns = [col.lower().replace(" ", "_") for col in df.columns]

print("Renamed Columns:")
print(df.columns.tolist())
# Out:
# Renamed Columns:
# ...

# %% [markdown]
# Dropping unnessisary data

# %%
# Adjust this list based on actual column names
columns_to_drop = [
    'timestamp',
    'race/ethnicity', 
    'gender', 
    'on_a_scale_of_1_to_5,_with_1_being_not_at_all_interested_and_5_being_extremely_interested,_how_interested_are_you_in_taking_more_computing_classes?',
    'please_explain_your_answer_to_the_question_above.__why_or_why_not_would_you_be_interested_in_taking_another_computing_class?',
]

# Create a new DataFrame with only the relevant columns
df_cleaned = df.drop(columns=columns_to_drop)

# Display the cleaned DataFrame
df_cleaned.head()
# Out:
#   which_course_are_you_enrolled_in?  \
# 0        CMP 128 Computer Science I
# 1                               NaN
# 2        CMP 128 Computer Science I
# 3        CMP 128 Computer Science I
# 4        CMP 128 Computer Science I
#
#   how_did_you_hear_about_county_college_of_morris?_[ccm_web_site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   how_did_you_hear_about_county_college_of_morris?_[social_media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
# ...

# %% [markdown]
# Condensing majors into more general major

# %%
df_cleaned['what_degree_program_are_you_currently_enrolled_in?'] = df_cleaned['what_degree_program_are_you_currently_enrolled_in?'].replace({
    'Mechanical Engineering Technology': 'Engineering',
    'Electronic engineering Technology': 'Engineering',
    'Mechanical Engineering Technology': 'Engineering',
    'engineering tech':'Engineering',
    'Mech Tech Engineering':'Engineering',
    'ELECTRONICS ENGINEERING TECHNOLOGY':'Engineering',
    'ELECTRONICS ENGINEERING TECH':'Engineering',
    'Mechanical Engineering':'Engineering',
    'mechanical engineering tech.':'Engineering',
    'mechanical engineering':'Engineering',
    'Electrical Engineer':'Engineering',
    'Mechanical Engineering Technologies':'Engineering',
    'electrical engineering technology':'Engineering',
    'Electronical Engineer':'Engineering',
    'Mechanical engineering technology':'Engineering',
    'Electronics Technolgies Engineering':'Engineering',
    'Engineering Science / Mechanical Engineering Technology':'Engineering',
    'Mechanical Engineering Tech':'Engineering',

    'Information Technology':'Computer Science',
    'CIS Game Development Option':'Computer Science',
    'Information Technology and Information Security Certificate of Achievement':'Computer Science',
    'Information Security Certificate of Achievement':'Computer Science',
    'Data Analytics Certificate of Achievement':'Computer Science',
    'Cybersecurity':'Computer Science',
    'cybersecurity':'Computer Science',
    'Information Technology & Info Security Certificate':'Computer Science',
    'Mechanical Engineering Technologist':'Engineering',
    'Web Development Certificate of Achievement':'Computer Science',
    'Electrical Engineering w/ biomed option':'Engineering',
    'Mech e':'Engineering',
    'Mech E':'Engineering',
    'MET':'Engineering',

})

# %% [markdown]
# Downloading new CSV

# %%
# Save the cleaned DataFrame as a new CSV file
cleaned_file_path = r"C:\Users\stewa\Downloads\Cleaned Majors Survey Results - Fall 2024.csv"
df_cleaned.to_csv(cleaned_file_path, index=False)
